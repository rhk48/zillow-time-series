# %% [markdown]
# ## EDA

# %%
# import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# ### Load in data

# %%
df = pd.read_csv('data/zillow_data.csv')

# %% [markdown]
# ### Inspecting data

# %%
df
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# 0           Cook         1  334200.0  335400.0  336500.0  ...  1005500
# 1         Collin         2  235700.0  236900.0  236700.0  ...   308000
# 2         Harris         3  210400.0  212200.0  212200.0  ...   321000
# 3           Cook         4  498100.0  500900.0  503100.0  ...  1289800
# 4        El Paso         5   77300.0   77300.0   77300.0  ...   119100
# ...          ...       ...       ...       ...       ...  ...      ...
# 14718   Franklin     14719   94600.0   94300.0   94000.0  ...   216800
# 14719    Grafton     14720   92700.0   92500.0   92400.0  ...   202100
# 14720    Madison     14721   57100.0   57300.0   57500.0  ...   121800
# 14721   Gunnison     14722  191100.0  192400.0  193700.0  ...   662800
# 14722      Clark     14723  176400.0  176300.0  176100.0  ...   333800
#
#        2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  \
# 0      1007500  1007800  1009600  1013300  1018700  1024400  1030700  1033800
# 1       310000   312500   314100   315000   316600   318100   319600   321100
# 2       320600   320200   320400   320800   321200   321200   323000   326900
# 3      1287700  1287400  1291500  1296600  1299000  1302700  1306400  1308500
# 4       119400   120000   120300   120300   120300   120300   120500   121000
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 14718   217700   218600   218500   218100   216400   213100   209800   209200
# 14719   208400   212200   215200   214300   213100   213700   218300   222700
# 14720   122800   124600   126700   128800   130600   131700   132500   133000
# 14721   671200   682400   695600   695500   694700   706400   705300   681500
# 14722   336400   339700   343800   346800   348900   350400   353000   356000
#
#        2018-04
# 0      1030600
# 1       321800
# 2       329900
# 3      1307000
# 4       121500
# ...        ...
# 14718   209300
# 14719   225800
# 14720   133400
# 14721   664400
# 14722   357200
#
# [14723 rows x 272 columns]

# %%
df.dtypes
# Out:
# RegionID       int64
# RegionName     int64
# City          object
# State         object
# Metro         object
#                ...
# 2017-12        int64
# 2018-01        int64
# 2018-02        int64
# 2018-03        int64
# 2018-04        int64
# Length: 272, dtype: object

# %%
df.isna().any().value_counts()
# Out:
# True     220
# False     52
# dtype: int64

# %% [markdown]
# ## Clean Data

# %%
# RegionID is something from Zillow, don't need it
df.drop('RegionID', axis=1,inplace=True)

# %% [markdown]
# ### Clean up column names

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
df['zipcode'] = df['regionname']
df['size_rank'] = df['sizerank']
df['county'] = df['countyname']
df.drop(['regionname', 'sizerank', 'countyname'],axis=1,inplace=True)
df
# Out:
#                       city state              metro   1996-04   1996-05  \
# 0                  Chicago    IL            Chicago  334200.0  335400.0
# 1                 McKinney    TX  Dallas-Fort Worth  235700.0  236900.0
# 2                     Katy    TX            Houston  210400.0  212200.0
# 3                  Chicago    IL            Chicago  498100.0  500900.0
# 4                  El Paso    TX            El Paso   77300.0   77300.0
# ...                    ...   ...                ...       ...       ...
# 14718             Ashfield    MA    Greenfield Town   94600.0   94300.0
# 14719            Woodstock    NH          Claremont   92700.0   92500.0
# 14720                Berea    KY           Richmond   57100.0   57300.0
# 14721  Mount Crested Butte    CO                NaN  191100.0  192400.0
# 14722             Mesquite    NV          Las Vegas  176400.0  176300.0
#
#         1996-06   1996-07   1996-08   1996-09   1996-10  ...  2017-10  \
# 0      336500.0  337600.0  338500.0  339500.0  340400.0  ...  1009600
# 1      236700.0  235400.0  233300.0  230600.0  227300.0  ...   314100
# 2      212200.0  210700.0  208300.0  205500.0  202500.0  ...   320400
# 3      503100.0  504600.0  505500.0  505700.0  505300.0  ...  1291500
# 4       77300.0   77300.0   77400.0   77500.0   77600.0  ...   120300
# ...         ...       ...       ...       ...       ...  ...      ...
# 14718   94000.0   93700.0   93400.0   93200.0   93000.0  ...   218500
# 14719   92400.0   92200.0   92100.0   91900.0   91700.0  ...   215200
# 14720   57500.0   57700.0   58000.0   58200.0   58400.0  ...   126700
# 14721  193700.0  195000.0  196300.0  197700.0  199100.0  ...   695600
# 14722  176100.0  176000.0  175900.0  175800.0  175800.0  ...   343800
#
#        2017-11  2017-12  2018-01  2018-02  2018-03  2018-04  zipcode  \
# 0      1013300  1018700  1024400  1030700  1033800  1030600    60657
# 1       315000   316600   318100   319600   321100   321800    75070
# 2       320800   321200   321200   323000   326900   329900    77494
# 3      1296600  1299000  1302700  1306400  1308500  1307000    60614
# 4       120300   120300   120300   120500   121000   121500    79936
# ...        ...      ...      ...      ...      ...      ...      ...
# 14718   218100   216400   213100   209800   209200   209300     1338
# 14719   214300   213100   213700   218300   222700   225800     3293
# 14720   128800   130600   131700   132500   133000   133400    40404
# 14721   695500   694700   706400   705300   681500   664400    81225
# 14722   346800   348900   350400   353000   356000   357200    89155
#
#        size_rank    county
# 0              1      Cook
# 1              2    Collin
# 2              3    Harris
# 3              4      Cook
# 4              5   El Paso
# ...          ...       ...
# 14718      14719  Franklin
# 14719      14720   Grafton
# 14720      14721   Madison
# 14721      14722  Gunnison
# 14722      14723     Clark
#
# [14723 rows x 271 columns]

# %% [markdown]
# ### Adding statistical columns

# %%
#Calculate historical return on investment
df['roi'] = (df['2018-04']/df['1996-04'])-1
#Calculate standard deviation of monthly values
df['std']=df.loc[:,'1996-04':'2018-04'].std(skipna=True, axis=1)
#Calculate historical mean value
df['mean']=df.loc[:,'1996-04':'2018-04'].mean(skipna=True, axis=1)
#Calculate historical median value
df['median']=df.loc[:,'1996-04':'2018-04'].median(skipna=True,axis=1)
#Calculate coefficient of variance
df['cv']=df['std']/df['mean']
#Show calculated values
df[['zipcode','std','mean','roi','cv']].head()

upper_cv = df.cv.quantile(.75)
print(f'\nCV upper limit: {upper_cv}')

#Get the 5 zipcodes with highest ROIs within the firms risk profile.
zc_best5 = df[df['cv']<upper_cv].sort_values('roi',axis=0,ascending=False)[:5]
print('\n Best 5 Zipcodes on raw historical ROI scores:')
zc_best5[['zipcode','roi','cv', 'city', 'state']]
# Out:
# CV upper limit: 0.27686411291010293
#
#  Best 5 Zipcodes on raw historical ROI scores:
#        zipcode       roi        cv        city state
# 10905    15681  4.594444  0.255833  Loyalhanna    PA
# 11449    16023  3.915212  0.274544    Winfield    PA
# 10658    16056  3.827830  0.269526     Clinton    PA
# 9178     16055  3.576659  0.270178     Buffalo    PA
# 9721     15627  3.482234  0.276190       Derry    PA

# %% [markdown]
# ### Melt data

# %%
# we want to keep certain cols and get the years + dates
def melt_data(df):
    melted = pd.melt(df, id_vars=['zipcode', 'state', 'city', 'metro', 'size_rank', 'county', 'roi', 'cv','mean','median','std'], var_name='date')
    melted['date'] = pd.to_datetime(melted['date'], infer_datetime_format=True)
    melted['year'] = [d.year for d in melted.date]
    melted = melted.dropna(subset=['value'])
    return melted

# %%
df = melt_data(df)

# %%
df
# Out:
#          zipcode state                 city              metro  size_rank  \
# 0          60657    IL              Chicago            Chicago          1
# 1          75070    TX             McKinney  Dallas-Fort Worth          2
# 2          77494    TX                 Katy            Houston          3
# 3          60614    IL              Chicago            Chicago          4
# 4          79936    TX              El Paso            El Paso          5
# ...          ...   ...                  ...                ...        ...
# 3901590     1338    MA             Ashfield    Greenfield Town      14719
# 3901591     3293    NH            Woodstock          Claremont      14720
# 3901592    40404    KY                Berea           Richmond      14721
# 3901593    81225    CO  Mount Crested Butte                NaN      14722
# 3901594    89155    NV             Mesquite          Las Vegas      14723
#
#            county       roi        cv           mean     median  \
# 0            Cook  2.083782  0.256487  743978.867925   775600.0
# 1          Collin  0.365295  0.152680  219655.849057   205900.0
# 2          Harris  0.567966  0.143950  262110.566038   249700.0
# 3            Cook  1.623971  0.237364  974139.245283  1006300.0
# 4         El Paso  0.571798  0.178326  101875.471698   112400.0
# ...           ...       ...       ...            ...        ...
# 3901590  Franklin  1.212474  0.232707  165064.150943   182800.0
# 3901591   Grafton  1.435814  0.303073  162661.886792   182000.0
# 3901592   Madison  1.336252  0.182705   97273.584906   104400.0
# 3901593  Gunnison  2.476714  0.282105  483997.358491   525200.0
# 3901594     Clark  1.024943  0.310044  269845.660377   239500.0
#
#                    std       date     value  year
# 0        190821.103965 1996-04-01  334200.0  1996
# 1         33537.101427 1996-04-01  235700.0  1996
# 2         37730.794353 1996-04-01  210400.0  1996
# 3        231225.944628 1996-04-01  498100.0  1996
# 4         18167.079218 1996-04-01   77300.0  1996
# ...                ...        ...       ...   ...
# 3901590   38411.628676 2018-04-01  209300.0  2018
# 3901591   49298.400500 2018-04-01  225800.0  2018
# 3901592   17772.324320 2018-04-01  133400.0  2018
# 3901593  136538.282291 2018-04-01  664400.0  2018
# 3901594   83664.045840 2018-04-01  357200.0  2018
#
# [3744704 rows x 14 columns]

# %% [markdown]
# ### Datetime as index

# %%
# setting our 'date' col which is in DateTime to Index
df.set_index(df['date'],inplace=True)
df.drop('date', axis=1, inplace=True)

# %%
# inspecting the date range of the full dataset
df_range = pd.Timedelta((df.index.max()-df.index.min()),unit='days')

print('earliest date:', df.index.min(),'\n\n','most recent date:', df.index.max(),'\n\n a range of', str(df_range)[:9],
     'or', round(8035/365.25, 2), 'years.')
# Out:
# earliest date: 1996-04-01 00:00:00
#
#  most recent date: 2018-04-01 00:00:00
#
#  a range of 8035 days or 22.0 years.

# %% [markdown]
# ## Some quick looks

# %%
# how many total zipcodes in this 3.7m record dataset?
df_zips = df['zipcode'].unique()
len(df_zips)
# Out:
# 14723

# %%
df_prices = pd.DataFrame(df['value'])
df_prices.head()
# Out:
#                value
# date
# 1996-04-01  334200.0
# 1996-04-01  235700.0
# 1996-04-01  210400.0
# 1996-04-01  498100.0
# 1996-04-01   77300.0

# %%
avg_prices = df_prices.groupby('date').aggregate({'value':'mean'})
median_prices = df_prices.groupby('date').aggregate({'value': 'median'})
avg_prices.plot()
median_prices.plot(c='orange');

# %% [markdown]
# Although the mean numbers are higher than median, the trend is about the same.

# %%
std_prices = df_prices.groupby('date').aggregate({'value':'std'})
std_prices.plot(c='green');

# %% [markdown]
# ## Looking at ChiTown data

# %% [markdown]
# To get some idea of the data we're working with, let's see what's up with Chicago.

# %%
chi = df[df['city'] == 'Chicago']
chi
# Out:
#             zipcode state     city    metro  size_rank county       roi  \
# date
# 1996-04-01    60657    IL  Chicago  Chicago          1   Cook  2.083782
# 1996-04-01    60614    IL  Chicago  Chicago          4   Cook  1.623971
# 1996-04-01    60640    IL  Chicago  Chicago          8   Cook  2.615704
# 1996-04-01    60647    IL  Chicago  Chicago         17   Cook  2.832111
# 1996-04-01    60618    IL  Chicago  Chicago         20   Cook  2.255961
# ...             ...   ...      ...      ...        ...    ...       ...
# 2018-04-01    60656    IL  Chicago  Chicago       3157   Cook  0.828022
# 2018-04-01    60655    IL  Chicago  Chicago       3961   Cook  0.850438
# 2018-04-01    60646    IL  Chicago  Chicago       4041   Cook  1.033958
# 2018-04-01    60642    IL  Chicago  Chicago       4363   Cook  1.697010
# 2018-04-01    60633    IL  Chicago  Chicago       7864   Cook  0.450578
#
#                   cv           mean     median            std     value  year
# date
# 1996-04-01  0.256487  743978.867925   775600.0  190821.103965  334200.0  1996
# 1996-04-01  0.237364  974139.245283  1006300.0  231225.944628  498100.0  1996
# 1996-04-01  0.302850  553078.867925   585900.0  167499.870439  216500.0  1996
# 1996-04-01  0.332313  293135.471698   302500.0   97412.855511  122700.0  1996
# 1996-04-01  0.303729  316441.132075   328900.0   96112.225708  142600.0  1996
# ...              ...            ...        ...            ...       ...   ...
# 2018-04-01  0.229503  263675.094340   265200.0   60514.191161  304000.0  2018
# 2018-04-01  0.225908  192772.830189   199700.0   43548.942529  232600.0  2018
# 2018-04-01  0.222924  333294.716981   340600.0   74299.319724  401300.0  2018
# 2018-04-01  0.232323  424144.528302   438300.0   98538.344993  604400.0  2018
# 2018-04-01  0.224340  105211.698113    98300.0   23603.241442  113000.0  2018
#
# [10658 rows x 13 columns]

# %%
chi_zips = chi['zipcode'].unique()
chi_zips
# Out:
# array([60657, 60614, 60640, 60647, 60618, 60613, 60629, 60625, 60619,
#        60610, 60620, 60634, 60626, 60649, 60616, 60622, 60615, 60641,
#        60660, 60608, 60638, 60639, 60630, 60643, 60632, 60605, 60645,
#        60651, 60653, 60654, 60612, 60607, 60659, 60652, 60631, 60656,
#        60655, 60646, 60642, 60633, 60611], dtype=int64)

# %%
chi_counties = chi['county'].unique()
chi_counties
# Out:
# array(['Cook'], dtype=object)

# %%
# looking at the housing IQR over time
chi_25 = chi['value'].quantile(.25)
chi_75 = chi['value'].quantile(.75)
print(f"""Chicago's houses for the most part fall between
${chi_25} and ${chi_75}""")
# Out:
# Chicago's houses for the most part fall between
# $162125.0 and $416100.0

# %%
# making sure Chicago's timeframe matches too
chi_range = pd.Timedelta((chi.index.max()-chi.index.min()),unit='days')
print('earliest date:', chi.index.min(),'\n\n','most recent date:', chi.index.max(),'\n\n a range of', str(chi_range)[:9],
     'or', round(8035/365.25, 2), 'years.')
# Out:
# earliest date: 1996-04-01 00:00:00
#
#  most recent date: 2018-04-01 00:00:00
#
#  a range of 8035 days or 22.0 years.

# %%
# any nulls?
chi.isna().any()
# Out:
# zipcode      False
# state        False
# city         False
# metro        False
# size_rank    False
# county       False
# roi           True
# cv           False
# mean         False
# median       False
# std          False
# value        False
# year         False
# dtype: bool

# %%
chi.roi.isna().sum()
# Out:
# 58

# %% [markdown]
# ### Some basic plotting

# %%
chi['value'].plot(figsize=(15,8));

# %%
chicago_pricing = pd.DataFrame(chi['value'])
chicago_mean = chicago_pricing.groupby('date').aggregate({'value':'mean'}).plot()
chicago_median = chicago_pricing.groupby('date').aggregate({'value':'median'}).plot(c='orange');

# %%
# reminder of what the full df looks like
avg_prices.plot()
median_prices.plot(c='orange');

# %%
chicago_std = chi.groupby('date').aggregate({'value':'std'})
chicago_std.plot(c='green');

# %%
std_prices.plot(c='green');

# %%
chicago_post_crash = chi['2007-09-01':]
chicago_post_crash['value']
chicago_08 = chicago_post_crash.groupby('date').aggregate({'value':'median'})
chicago_08.plot();

# %% [markdown]
# ### Chicago Augmented Dicky-Fuller

# %%
def stationarity_check(df):
    roll_mean = df.rolling(window=12, center=False).mean()
    roll_std = df.rolling(window=12, center=False).std()
    
    df_test = adfuller(df)
    print('Results of Dickey-Fuller Test: \n')

    dfoutput = pd.Series(df_test[0:4], index=['Test Statistic', 'p-value', 
                                             '#Lags Used', 'Number of Observations Used'])
    for key,value in df_test[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    roll_mean.plot()
    roll_std.plot()
    return df_test

# %%
chi.head()
# Out:
#             zipcode state     city    metro  size_rank county       roi  \
# date
# 1996-04-01    60657    IL  Chicago  Chicago          1   Cook  2.083782
# 1996-04-01    60614    IL  Chicago  Chicago          4   Cook  1.623971
# 1996-04-01    60640    IL  Chicago  Chicago          8   Cook  2.615704
# 1996-04-01    60647    IL  Chicago  Chicago         17   Cook  2.832111
# 1996-04-01    60618    IL  Chicago  Chicago         20   Cook  2.255961
#
#                   cv           mean     median            std     value  year
# date
# 1996-04-01  0.256487  743978.867925   775600.0  190821.103965  334200.0  1996
# 1996-04-01  0.237364  974139.245283  1006300.0  231225.944628  498100.0  1996
# 1996-04-01  0.302850  553078.867925   585900.0  167499.870439  216500.0  1996
# 1996-04-01  0.332313  293135.471698   302500.0   97412.855511  122700.0  1996
# 1996-04-01  0.303729  316441.132075   328900.0   96112.225708  142600.0  1996

# %%
stationarity_check(chi['value'])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                    -3.197103
# p-value                            0.020153
# #Lags Used                        39.000000
# Number of Observations Used    10618.000000
# Critical Value (1%)               -3.430966
# Critical Value (5%)               -2.861812
# Critical Value (10%)              -2.566915
# dtype: float64
# (-3.1971025302045866,
#  0.02015300993749242,
#  39,
#  10618,
#  {'1%': -3.4309660182336517,
#   '5%': -2.8618122451602916,
#   '10%': -2.5669149109578795},
#  284578.8809224252)

# %%
print('Results of Dicky-Fuller Test for Chicago: \n')
dftest = adfuller(chi['value'])

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)' %key] = value
print(dfoutput)
# Out:
# Results of Dicky-Fuller Test for Chicago:
#
# Test Statistic                    -3.197103
# p-value                            0.020153
# #Lags Used                        39.000000
# Number of Observations Used    10618.000000
# Critical Value (1%)               -3.430966
# Critical Value (5%)               -2.861812
# Critical Value (10%)              -2.566915
# dtype: float64

# %%
# doing this on only 100,000 data points from the original df because I don't want to break my computer again
sample_df = df.sample(frac=1)
stationarity_check(sample_df['value'][:100000])
# Out:
# Results of Dickey-Fuller Test:
#
# Test Statistic                  -315.094855
# p-value                            0.000000
# #Lags Used                         0.000000
# Number of Observations Used    99999.000000
# Critical Value (1%)               -3.430415
# Critical Value (5%)               -2.861569
# Critical Value (10%)              -2.566785
# dtype: float64
# (-315.0948552449194,
#  0.0,
#  0,
#  99999,
#  {'1%': -3.4304153953326493,
#   '5%': -2.8615689037124814,
#   '10%': -2.566785384434747},
#  2762652.1924648597)

# %% [markdown]
# ### More sandboxing with Chicago

# %%
chi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10658 entries, 1996-04-01 to 2018-04-01
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   zipcode    10658 non-null  int64
#  1   state      10658 non-null  object
#  2   city       10658 non-null  object
#  3   metro      10658 non-null  object
#  4   size_rank  10658 non-null  int64
#  5   county     10658 non-null  object
#  6   roi        10600 non-null  float64
#  7   cv         10658 non-null  float64
#  8   mean       10658 non-null  float64
#  9   median     10658 non-null  float64
#  10  std        10658 non-null  float64
#  11  value      10658 non-null  float64
#  12  year       10658 non-null  int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
chi.head()
# Out:
#             zipcode state     city    metro  size_rank county       roi  \
# date
# 1996-04-01    60657    IL  Chicago  Chicago          1   Cook  2.083782
# 1996-04-01    60614    IL  Chicago  Chicago          4   Cook  1.623971
# 1996-04-01    60640    IL  Chicago  Chicago          8   Cook  2.615704
# 1996-04-01    60647    IL  Chicago  Chicago         17   Cook  2.832111
# 1996-04-01    60618    IL  Chicago  Chicago         20   Cook  2.255961
#
#                   cv           mean     median            std     value  year
# date
# 1996-04-01  0.256487  743978.867925   775600.0  190821.103965  334200.0  1996
# 1996-04-01  0.237364  974139.245283  1006300.0  231225.944628  498100.0  1996
# 1996-04-01  0.302850  553078.867925   585900.0  167499.870439  216500.0  1996
# 1996-04-01  0.332313  293135.471698   302500.0   97412.855511  122700.0  1996
# 1996-04-01  0.303729  316441.132075   328900.0   96112.225708  142600.0  1996

# %%
chi_years = chi.groupby('date').mean()

# %%
chi_years.set_index('year')
# Out:
#              zipcode    size_rank       roi        cv           mean  \
# year
# 1996.0  60633.650000  1295.550000  1.411592  0.262096  340033.490566
# 1996.0  60633.650000  1295.550000  1.411592  0.262096  340033.490566
# 1996.0  60633.650000  1295.550000  1.411592  0.262096  340033.490566
# 1996.0  60633.650000  1295.550000  1.411592  0.262096  340033.490566
# 1996.0  60633.650000  1295.550000  1.411592  0.262096  340033.490566
# ...              ...          ...       ...       ...            ...
# 2017.0  60633.097561  1266.536585  1.411592  0.256854  365474.347398
# 2018.0  60633.097561  1266.536585  1.411592  0.256854  365474.347398
# 2018.0  60633.097561  1266.536585  1.411592  0.256854  365474.347398
# 2018.0  60633.097561  1266.536585  1.411592  0.256854  365474.347398
# 2018.0  60633.097561  1266.536585  1.411592  0.256854  365474.347398
#
#                median           std          value
# year
# 1996.0  349265.000000  88769.487314  176757.500000
# 1996.0  349265.000000  88769.487314  177220.000000
# 1996.0  349265.000000  88769.487314  177500.000000
# 1996.0  349265.000000  88769.487314  177560.000000
# 1996.0  349265.000000  88769.487314  177435.000000
# ...               ...           ...            ...
# 2017.0  373896.341463  88194.848716  474153.658537
# 2018.0  373896.341463  88194.848716  476026.829268
# 2018.0  373896.341463  88194.848716  477909.756098
# 2018.0  373896.341463  88194.848716  478475.609756
# 2018.0  373896.341463  88194.848716  477292.682927
#
# [265 rows x 8 columns]

# %%
chi_years.groupby('year')

# %%
chi_years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 265 entries, 1996-04-01 to 2018-04-01
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   zipcode    265 non-null    float64
#  1   size_rank  265 non-null    float64
#  2   roi        265 non-null    float64
#  3   cv         265 non-null    float64
#  4   mean       265 non-null    float64
#  5   median     265 non-null    float64
#  6   std        265 non-null    float64
#  7   value      265 non-null    float64
#  8   year       265 non-null    float64
# dtypes: float64(9)
# memory usage: 20.7 KB

# %%
year_groups = chi_years.groupby(pd.Grouper(freq='A'))

# %%
chi_annual = pd.DataFrame()

# %% [markdown]
# for yr, group in year_groups:
#     chi_annual[yr.year] = group.values.ravel()
#
# chi_annual.plot(figsize=(13,8),subplots=True,legend=True);

# %%
chi_mean = chi['value'].rolling(12).mean()
chi_std = chi['value'].rolling(12).std()

# %%
fig = plt.figure(figsize=(15,6))
plt.plot(chi['value'], color='blue',label='Original')
plt.plot(chi_mean, color='red',label='Rolling Mean')
plt.plot(chi_std, color='gray',label='Rolling Std')
plt.legend(loc='best')
plt.title('Chi Rolling Mean and Std')
plt.show();

# %% [markdown]
# ### Random Walk

# %%
xr = chi
xr['value'].plot(figsize=(14,5), color='orange');

# %%
dates = pd.date_range('1996-04-01', '2018-04-01', freq='B')
len(dates)
# Out:
# 5740

# %%
chi_values = np.random.normal(chi['value'].mean(), chi['value'].std(), len(dates))
chi_series = pd.Series(chi_values, index=dates)

# %%
ax = chi_series.plot(figsize=(14,6))
ax.set_ylabel('House value', fontsize=16)
ax.set_xlabel('Date', fontsize=16)
plt.show();

# %%
print(min(chi_values), '\n\n', max(chi_values))
# Out:
# -582215.1637800403
#
#  1263626.9325956237

# %%
chi_series.hist(grid=False);

# %%
print(chi_series.mean(), '\n\n', chi_series.std())
# Out:
# 346765.02901627327
#
#  259813.9741136049

# %%
error = np.random.normal(0, 10, len(dates))

def random_walk(start, error):
    Y_0 = start
    cum_error = np.cumsum(error)
    Y = cum_error + Y_0
    return Y

chi_house_values = random_walk(1000, error)

chi_house_series = pd.Series(chi_house_values, index=dates)

# %%
ax = chi_house_series.plot(figsize=(14,6))
ax.set_ylabel('House value', fontsize=16)
ax.set_xlabel('Date', fontsize=16)
plt.show();

# %%
chi_diff = chi_house_series.diff(periods=1)

fig = plt.figure(figsize=(18,6))
plt.plot(chi_diff)
plt.title('Differenced house prices')
plt.show(block=False);

# %%
chi_house_values_drift = random_walk(1000, error)

chi_house_series_drift = pd.Series(chi_values, index=dates)

# %%
chi_drift_diff = chi_house_series_drift.diff(periods=1)

fig = plt.figure(figsize=(18,6))
plt.plot(chi_drift_diff)
plt.title('Differenced house prices with drift')
plt.show(block=False);

# %%
error = np.random.normal(0, 2, len(dates))
Y_0 = 8
mu = chi['value'].mean()
phi = .7

# %%
TS = [None] * len(dates)
y = Y_0
for i, row in enumerate(dates):
    TS[i] = mu + y * phi + error[i]
    y = TS[i] - mu

# %%
new_chi_series = pd.Series(TS, index=dates)
new_chi_series.plot(figsize=(14,6), linewidth=2, fontsize=14);

# %%
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf

fig, ax = plt.subplots(figsize=(16,3))
plot_acf(new_chi_series, ax=ax, lags=40);

fig, ax = plt.subplots(figsize=(16,3))
plot_pacf(new_chi_series, ax=ax, lags=40);

# %% [markdown]
# ### ARMA

# %%
from statsmodels.tsa.arima_model import ARMA
import statsmodels.api as sm
import warnings

# instantiate an AR(1) model to the simulated data
mod_arma = ARMA(new_chi_series, order=(1,0))
warnings.filterwarnings('ignore')
# Out:
# C:\Users\sethk\anaconda3\envs\learn-env\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)

# %%
# fit the model
res_arma = mod_arma.fit()

# %%
print(res_arma.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 5740
# Model:                     ARMA(1, 0)   Log Likelihood              -12142.295
# Method:                       css-mle   S.D. of innovations              2.006
# Date:                Tue, 05 Oct 2021   AIC                          24290.590
# Time:                        09:53:41   BIC                          24310.555
# Sample:                    04-01-1996   HQIC                         24297.539
#                          - 03-30-2018
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.457e+05      0.088   3.91e+06      0.000    3.46e+05    3.46e+05
# ar.L1.y        0.6983      0.009     73.794      0.000       0.680       0.717
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.4320           +0.0000j            1.4320            0.0000
# -----------------------------------------------------------------------------

# %%
res_arma.params
# Out:
# const      345709.909724
# ar.L1.y         0.698300
# dtype: float64

# %%
np.random.seed(42)

error = np.random.normal(0, 4, len(dates))
theta = 0.9

TS = [None] * len(dates)
error_prev = error[0]
for i, row in enumerate(dates):
    TS[i] = mu + theta * error_prev + error[i]
    error_prev = error[i]

# %%
another_chi_series = pd.Series(TS, index=dates)

another_chi_series.plot(figsize=(14,6), linewidth=2, fontsize=14);

# %%
fig, ax = plt.subplots(figsize=(16,3))
plot_acf(another_chi_series,ax=ax,lags=40);

fig, ax = plt.subplots(figsize=(16,3))
plot_pacf(another_chi_series,ax=ax,lags=40);

# %%
# Instantiate and fit an MA(1) model to the simulated data
mod_arma = ARMA(another_chi_series, order=(0,1))
res_arma = mod_arma.fit()

# Print out summary information on the fit
print(res_arma.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 5740
# Model:                     ARMA(0, 1)   Log Likelihood              -16067.892
# Method:                       css-mle   S.D. of innovations              3.976
# Date:                Tue, 05 Oct 2021   AIC                          32141.785
# Time:                        09:53:42   BIC                          32161.750
# Sample:                    04-01-1996   HQIC                         32148.734
#                          - 03-30-2018
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.457e+05      0.100   3.44e+06      0.000    3.46e+05    3.46e+05
# ma.L1.y        0.9057      0.006    162.073      0.000       0.895       0.917
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.1041           +0.0000j            1.1041            0.5000
# -----------------------------------------------------------------------------

# %%
print(res_arma.params)
# Out:
# const      345709.835212
# ma.L1.y         0.905698
# dtype: float64

# %% [markdown]
# ## New DF

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)
new_df = pd.read_csv('data/zillow_data.csv')
new_df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0         1  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 1         2  235700.0  236900.0  236700.0  235400.0  233300.0  230600.0
# 2         3  210400.0  212200.0  212200.0  210700.0  208300.0  205500.0
# 3         4  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 4         5   77300.0   77300.0   77300.0   77300.0   77400.0   77500.0
#
#     1996-10   1996-11   1996-12   1997-01   1997-02   1997-03   1997-04  \
#    2015-07  2015-08  2015-09  2015-10  2015-11  2015-12  2016-01  2016-02  \
# 0   917700   919800   925800   937100   948200   951000   952500   958600
# 1   268400   271400   273600   275200   276400   277000   277900   280000
# 2   314100   316300   319000   322000   324300   326100   327300   327000
# 3  1200400  1198900  1200200  1207400  1218600  1226600  1230700  1235400
# 4   115600   115400   115400   115500   115800   116300   116200   115600
#
#    2016-03  2016-04  2016-05  2016-06  2016-07  2016-08  2016-09  2016-10  \
# 0   966200   970400   973900   974700   972600   974300   980800   988000
# 1   282600   285400   288400   290800   292000   292800   293700   295200
# 2   327200   328500   329800   330000   329000   327800   326700   325500
# 3  1241300  1245700  1247000  1246700  1245700  1246000  1247700  1252900
# 4   115000   114500   114200   114000   114000   113900   114100   114900
#
#    2016-11  2016-12  2017-01  2017-02  2017-03  2017-04  2017-05  2017-06  \
# 0   994700   998700   997000   993700   991300   989200   991300   999100
# 1   297000   299000   300800   301800   302800   304400   306200   307000
# 2   324700   324500   323700   322300   320700   320000   320000   320900
# 3  1260900  1267900  1272600  1276600  1280300  1282500  1286000  1289000
# 4   115700   116300   116900   117300   117600   118000   118600   118900
#
#    2017-07  2017-08  2017-09  2017-10  2017-11  2017-12  2018-01  2018-02  \
# 0  1005500  1007500  1007800  1009600  1013300  1018700  1024400  1030700
# 1   308000   310000   312500   314100   315000   316600   318100   319600
# 2   321000   320600   320200   320400   320800   321200   321200   323000
# 3  1289800  1287700  1287400  1291500  1296600  1299000  1302700  1306400
# 4   119100   119400   120000   120300   120300   120300   120300   120500
#
#    2018-03  2018-04
# 0  1033800  1030600
# 1   321100   321800
# 2   326900   329900
# 3  1308500  1307000
# 4   121000   121500

# %%
new_df_cols = new_df.columns
new_df_cols[6:100]
# Out:
# Index(['SizeRank', '1996-04', '1996-05', '1996-06', '1996-07', '1996-08',
#        '1996-09', '1996-10', '1996-11', '1996-12', '1997-01', '1997-02',
#        '1997-03', '1997-04', '1997-05', '1997-06', '1997-07', '1997-08',
#        '1997-09', '1997-10', '1997-11', '1997-12', '1998-01', '1998-02',
#        '1998-03', '1998-04', '1998-05', '1998-06', '1998-07', '1998-08',
#        '1998-09', '1998-10', '1998-11', '1998-12', '1999-01', '1999-02',
#        '1999-03', '1999-04', '1999-05', '1999-06', '1999-07', '1999-08',
#        '1999-09', '1999-10', '1999-11', '1999-12', '2000-01', '2000-02',
#        '2000-03', '2000-04', '2000-05', '2000-06', '2000-07', '2000-08',
#        '2000-09', '2000-10', '2000-11', '2000-12', '2001-01', '2001-02',
#        '2001-03', '2001-04', '2001-05', '2001-06', '2001-07', '2001-08',
#        '2001-09', '2001-10', '2001-11', '2001-12', '2002-01', '2002-02',
#        '2002-03', '2002-04', '2002-05', '2002-06', '2002-07', '2002-08',
#        '2002-09', '2002-10', '2002-11', '2002-12', '2003-01', '2003-02',
#        '2003-03', '2003-04', '2003-05', '2003-06', '2003-07', '2003-08',
#        '2003-09', '2003-10', '2003-11', '2003-12'],
#       dtype='object')

# %%
new_df.drop(new_df_cols[6:100])
