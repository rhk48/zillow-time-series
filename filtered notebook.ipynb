# %%
# import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from math import sqrt
from math import log
from math import exp
from scipy.stats import boxcox 
from pandas import DataFrame
from pandas import Grouper
from pandas import Series
from pandas import concat
from pandas.plotting import lag_plot
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMAResults
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.gofplots import qqplot

# %%
raw_df = pd.read_csv('zillow_data.csv')

# %%
zip_codes = pd.read_csv('zip_codes_2019_median_inc.csv')
zip_codes['Preferred name']
# Out:
# 0         Holtsville, NY
# 1         Holtsville, NY
# 2           Adjuntas, PR
# 3             Aguada, PR
# 4          Aguadilla, PR
#               ...
# 41271     Metlakatla, AK
# 41272    Point Baker, AK
# 41273      Ward Cove, AK
# 41274       Wrangell, AK
# 41275      Ketchikan, AK
# Name: Preferred name, Length: 41276, dtype: object

# %%
zip_codes['state'] = zip_codes['Preferred name'].str.slice(-2)
zip_codes
# Out:
#        ZIP Code      Type  State FIPS   Preferred name  \
# 0           501    unique          36   Holtsville, NY
# 1           544    unique          36   Holtsville, NY
# 2           601  standard          72     Adjuntas, PR
# 3           602  standard          72       Aguada, PR
# 4           603  standard          72    Aguadilla, PR
# ...         ...       ...         ...              ...
# 41271     99926    PO box           2   Metlakatla, AK
# 41272     99927    PO box           2  Point Baker, AK
# 41273     99928    PO box           2    Ward Cove, AK
# 41274     99929    PO box           2     Wrangell, AK
# 41275     99950    PO box           2    Ketchikan, AK
#
#                                          Alternate names Population (2019)  \
# 0                                     IRS Service Center               NaN
# 1                                     IRS Service Center               NaN
# 2      Colinas Del Gigante, Jard De Adjuntas, Urb San...            17,113
# 3      Alts De Aguada, Bo Guaniquilla, Comunidad Las ...            37,751
# 4      Ramey, Bda Caban, Bda Esteves, Bo Borinquen, B...            47,081
# ...                                                  ...               ...
# 41271                                                NaN             1,654
# 41272                                                NaN                 0
# 41273                                                NaN               NaN
# 41274                                                NaN             2,502
# 41275                                   Edna Bay, Kasaan               NaN
#
#       Housing units (2019) Median family income (2019)  MFI percentile (2019)  \
# 0                      NaN                         NaN                    NaN
# 1                      NaN                         NaN                    NaN
# 2                    7,250                     $16,001                    0.0
# 3                   17,538                     $19,801                    0.0
# 4                   24,322                     $18,973                    0.0
# ...                    ...                         ...                    ...
# 41271                  552                     $70,455                   53.0
# 41272                   54                         NaN                    NaN
# 41273                  NaN                         NaN                    NaN
# 41274                1,463                     $69,600                   52.0
# 41275                  NaN                         NaN                    NaN
#
#         Latitude   Longitude  Land area  Water area state
# 0            NaN         NaN        NaN         NaN    NY
# 1            NaN         NaN        NaN         NaN    NY
# 2      18.181000  -66.750000     64.348       0.309    PR
# 3      18.362000  -67.176003     30.613       1.718    PR
# 4      18.455000  -67.120003     31.616       0.071    PR
# ...          ...         ...        ...         ...   ...
# 41271  55.138000 -131.470001    132.798      82.369    AK
# 41272  56.238998 -133.457993    227.680       6.950    AK
# 41273        NaN         NaN        NaN         NaN    AK
# 41274  56.370998 -131.692993    999.999     246.117    AK
# 41275        NaN         NaN        NaN         NaN    AK
#
# [41276 rows x 14 columns]

# %%
zip_codes = zip_codes[zip_codes['state']=='TX']
zip_codes = (zip_codes[zip_codes['Type'] != 'PO box'])
zip_codes
# Out:
#        ZIP Code      Type  State FIPS  Preferred name  \
# 31142     73301    unique          48      Austin, TX
# 31143     73344    unique          48      Austin, TX
# 31744     75001  standard          48     Addison, TX
# 31745     75002  standard          48       Allen, TX
# 31746     75006  standard          48  Carrollton, TX
# ...         ...       ...         ...             ...
# 34257     79961    unique          48     El Paso, TX
# 34258     79968    unique          48     El Paso, TX
# 34259     79976    unique          48     El Paso, TX
# 34260     79978    unique          48     El Paso, TX
# 34261     79980    unique          48     El Paso, TX
#
#                Alternate names Population (2019) Housing units (2019)  \
# 31142       Irs Service Center               NaN                  NaN
# 31143       Irs Service Center               NaN                  NaN
# 31744                      NaN            14,992                9,298
# 31745            Lucas, Parker            71,253               23,314
# 31746                      NaN            51,642               19,178
# ...                        ...               ...                  ...
# 34257  El Paso Water Utilities               NaN                  NaN
# 34258           Univ Of Tx Elp               NaN                  NaN
# 34259    Southern Union Gas Co               NaN                  NaN
# 34260      El Paso Natural Gas               NaN                  NaN
# 34261         Wells Fargo Bank               NaN                  NaN
#
#       Median family income (2019)  MFI percentile (2019)   Latitude  \
# 31142                         NaN                    NaN        NaN
# 31143                         NaN                    NaN        NaN
# 31744                     $79,551                   68.0  32.959999
# 31745                    $105,656                   88.0  33.090000
# 31746                     $72,325                   57.0  32.962002
# ...                           ...                    ...        ...
# 34257                         NaN                    NaN        NaN
# 34258                         NaN                    NaN        NaN
# 34259                         NaN                    NaN        NaN
# 34260                         NaN                    NaN        NaN
# 34261                         NaN                    NaN        NaN
#
#        Longitude  Land area  Water area state
# 31142        NaN        NaN         NaN    TX
# 31143        NaN        NaN         NaN    TX
# 31744 -96.838997      3.834       0.003    TX
# 31745 -96.609001     37.179       2.056    TX
# 31746 -96.899002     16.875       0.254    TX
# ...          ...        ...         ...   ...
# 34257        NaN        NaN         NaN    TX
# 34258        NaN        NaN         NaN    TX
# 34259        NaN        NaN         NaN    TX
# 34260        NaN        NaN         NaN    TX
# 34261        NaN        NaN         NaN    TX
#
# [1839 rows x 14 columns]

# %%
raw_df.drop(raw_df.columns[np.r_[0, 4, 6:100]], axis=1, inplace=True)

# %%
raw_df = raw_df[raw_df['State'] == 'TX']

# %%
raw_df
# Out:
#        RegionName           City State CountyName   2004-01   2004-02  \
# 1           75070       McKinney    TX     Collin  187700.0  188800.0
# 2           77494           Katy    TX     Harris  231800.0  233100.0
# 4           79936        El Paso    TX    El Paso   84000.0   84700.0
# 5           77084        Houston    TX     Harris  119400.0  120400.0
# 8           77449           Katy    TX     Harris  123900.0  125300.0
# ...           ...            ...   ...        ...       ...       ...
# 14372       76941        Mertzon    TX      Irion       NaN       NaN
# 14472       79313          Anton    TX    Hockley       NaN       NaN
# 14492       79355         Plains    TX     Yoakum       NaN       NaN
# 14599       79366  Ransom Canyon    TX    Lubbock  161900.0  162300.0
# 14695       77457      Matagorda    TX  Matagorda  124800.0  125800.0
#
#         2004-03   2004-04   2004-05   2004-06  ...  2017-07  2017-08  2017-09  \
# 1      190300.0  191800.0  193000.0  193900.0  ...   308000   310000   312500
# 2      233500.0  233000.0  232100.0  231300.0  ...   321000   320600   320200
# 4       85500.0   86400.0   87200.0   88000.0  ...   119100   119400   120000
# 5      121200.0  121900.0  122400.0  122700.0  ...   157900   158700   160200
# 8      126600.0  127500.0  128100.0  128500.0  ...   166800   167400   168400
# ...         ...       ...       ...       ...  ...      ...      ...      ...
# 14372       NaN       NaN       NaN       NaN  ...   122500   121800   121600
# 14472       NaN       NaN       NaN       NaN  ...    55400    56300    55700
# 14492       NaN       NaN       NaN       NaN  ...   100500   100500   101000
# 14599  162700.0  163100.0  163400.0  163600.0  ...   252100   251600   251600
# 14695  127000.0  128300.0  129500.0  130800.0  ...   250400   253300   256900
#
#        2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 1       314100   315000   316600   318100   319600   321100   321800
# 2       320400   320800   321200   321200   323000   326900   329900
# 4       120300   120300   120300   120300   120500   121000   121500
# 5       161900   162800   162800   162800   162900   163500   164300
# 8       169600   170900   172300   173300   174200   175400   176200
# ...        ...      ...      ...      ...      ...      ...      ...
# 14372   122200   123500   124700   124300   122600   121600   121600
# 14472    56300    58900    61500    63000    63600    63500    63300
# 14492   100700    99700    97700    95800    94600    94000    93500
# 14599   251500   251300   251500   251700   252500   255000   257500
# 14695   256100   250700   243200   238300   234200   230500   227300
#
# [989 rows x 176 columns]

# %%
raw_df.quantile(.25)
# Out:
# RegionName     76021.0
# 2004-01        78700.0
# 2004-02        79300.0
# 2004-03        80100.0
# 2004-04        80700.0
#                 ...
# 2017-12       112700.0
# 2018-01       113000.0
# 2018-02       113900.0
# 2018-03       115000.0
# 2018-04       115400.0
# Name: 0.25, Length: 173, dtype: float64

# %%
#Calculate historical return on investment
raw_df['ROI']= (raw_df['2018-04']/raw_df['2004-01'])-1
raw_df['ROI']


#Calculate standard deviation of monthly values
raw_df['std']=raw_df.loc[:,'2004-01':'2018-04'].std(skipna=True, axis=1)

#Calculate historical mean value
raw_df['mean']=raw_df.loc[:,'2004-01':'2018-04'].mean(skipna=True, axis=1)

#Calculate coefficient of variance
raw_df['CV']=raw_df['std']/raw_df['mean']

#Show calculated values
raw_df[['RegionName','std','mean','ROI','CV']].head()

#Descriptive statistics of coefficients of variance.
print(raw_df.CV.describe())

#Define upper limit of CV according to risk profile.
upper_cv = raw_df.CV.quantile(.6)
print(f'\nCV upper limit: {upper_cv}')

#Get the 5 zipcodes with highest ROIs within the firms risk profile.
zc_best5 = raw_df[raw_df['CV']<upper_cv].sort_values('ROI',axis=0,ascending=False)[:5]
print('\n Best 5 Zipcodes:')
zc_best5[['RegionName','ROI','CV']]
# Out:
# count    989.000000
# mean       0.121449
# std        0.036183
# min        0.019827
# 25%        0.098176
# 50%        0.120857
# 75%        0.142168
# max        0.293064
# Name: CV, dtype: float64
#
# CV upper limit: 0.12848011113068844
#
#  Best 5 Zipcodes:
#        RegionName       ROI        CV
# 9851        76050  0.943470  0.117471
# 7776        78204  0.848754  0.119656
# 11091       77514  0.845737  0.126108
# 2901        77550  0.843943  0.120857
# 4807        79602  0.830396  0.124068

# %%
raw_df
# Out:
#        RegionName           City State CountyName   2004-01   2004-02  \
# 1           75070       McKinney    TX     Collin  187700.0  188800.0
# 2           77494           Katy    TX     Harris  231800.0  233100.0
# 4           79936        El Paso    TX    El Paso   84000.0   84700.0
# 5           77084        Houston    TX     Harris  119400.0  120400.0
# 8           77449           Katy    TX     Harris  123900.0  125300.0
# ...           ...            ...   ...        ...       ...       ...
# 14372       76941        Mertzon    TX      Irion       NaN       NaN
# 14472       79313          Anton    TX    Hockley       NaN       NaN
# 14492       79355         Plains    TX     Yoakum       NaN       NaN
# 14599       79366  Ransom Canyon    TX    Lubbock  161900.0  162300.0
# 14695       77457      Matagorda    TX  Matagorda  124800.0  125800.0
#
#         2004-03   2004-04   2004-05   2004-06  ...  2017-11  2017-12  2018-01  \
# 1      190300.0  191800.0  193000.0  193900.0  ...   315000   316600   318100
# 2      233500.0  233000.0  232100.0  231300.0  ...   320800   321200   321200
# 4       85500.0   86400.0   87200.0   88000.0  ...   120300   120300   120300
# 5      121200.0  121900.0  122400.0  122700.0  ...   162800   162800   162800
# 8      126600.0  127500.0  128100.0  128500.0  ...   170900   172300   173300
# ...         ...       ...       ...       ...  ...      ...      ...      ...
# 14372       NaN       NaN       NaN       NaN  ...   123500   124700   124300
# 14472       NaN       NaN       NaN       NaN  ...    58900    61500    63000
# 14492       NaN       NaN       NaN       NaN  ...    99700    97700    95800
# 14599  162700.0  163100.0  163400.0  163600.0  ...   251300   251500   251700
# 14695  127000.0  128300.0  129500.0  130800.0  ...   250700   243200   238300
#
#        2018-02  2018-03  2018-04       ROI           std           mean  \
# 1       319600   321100   321800  0.714438  38257.775512  227040.116279
# 2       323000   326900   329900  0.423210  33208.367605  266633.139535
# 4       120500   121000   121500  0.446429  10248.462666  113729.651163
# 5       162900   163500   164300  0.376047  14170.210695  130143.604651
# 8       174200   175400   176200  0.422115  16508.811448  134945.348837
# ...        ...      ...      ...       ...           ...            ...
# 14372   122600   121600   121600       NaN  13734.029878   99318.367347
# 14472    63600    63500    63300       NaN   5286.674724   54424.675325
# 14492    94600    94000    93500       NaN  12929.465872   78967.346939
# 14599   252500   255000   257500  0.590488  25909.956515  189098.837209
# 14695   234200   230500   227300  0.821314  32480.802116  175802.906977
#
#              CV
# 1      0.168507
# 2      0.124547
# 4      0.090112
# 5      0.108881
# 8      0.122337
# ...         ...
# 14372  0.138283
# 14472  0.097137
# 14492  0.163732
# 14599  0.137018
# 14695  0.184757
#
# [989 rows x 180 columns]

# %%
#from sklearn.impute import SimpleImputer

#imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')

#texas = imp_mean.fit_transform(texas)

#texas

# %%
def melt_data(raw_df):
    melted = pd.melt(raw_df, id_vars=['RegionName', 'City', 'CountyName', 'ROI', 'State', 'std', 'mean', 'CV'], var_name='date')
    melted['date'] = pd.to_datetime(melted['date'], infer_datetime_format=True)
    melted['year'] = [d.year for d in melted.date]
    melted = melted.dropna(subset=['value'])
    return melted

# %%
df = melt_data(raw_df)
df
# Out:
#         RegionName           City CountyName       ROI State           std  \
# 0            75070       McKinney     Collin  0.714438    TX  38257.775512
# 1            77494           Katy     Harris  0.423210    TX  33208.367605
# 2            79936        El Paso    El Paso  0.446429    TX  10248.462666
# 3            77084        Houston     Harris  0.376047    TX  14170.210695
# 4            77449           Katy     Harris  0.422115    TX  16508.811448
# ...            ...            ...        ...       ...   ...           ...
# 170103       76941        Mertzon      Irion       NaN    TX  13734.029878
# 170104       79313          Anton    Hockley       NaN    TX   5286.674724
# 170105       79355         Plains     Yoakum       NaN    TX  12929.465872
# 170106       79366  Ransom Canyon    Lubbock  0.590488    TX  25909.956515
# 170107       77457      Matagorda  Matagorda  0.821314    TX  32480.802116
#
#                  mean        CV       date     value  year
# 0       227040.116279  0.168507 2004-01-01  187700.0  2004
# 1       266633.139535  0.124547 2004-01-01  231800.0  2004
# 2       113729.651163  0.090112 2004-01-01   84000.0  2004
# 3       130143.604651  0.108881 2004-01-01  119400.0  2004
# 4       134945.348837  0.122337 2004-01-01  123900.0  2004
# ...               ...       ...        ...       ...   ...
# 170103   99318.367347  0.138283 2018-04-01  121600.0  2018
# 170104   54424.675325  0.097137 2018-04-01   63300.0  2018
# 170105   78967.346939  0.163732 2018-04-01   93500.0  2018
# 170106  189098.837209  0.137018 2018-04-01  257500.0  2018
# 170107  175802.906977  0.184757 2018-04-01  227300.0  2018
#
# [167292 rows x 11 columns]

# %%
df.set_index(df['date'], inplace = True)
df.drop('date',axis=1, inplace=True)
df
# Out:
#             RegionName           City CountyName       ROI State  \
# date
# 2004-01-01       75070       McKinney     Collin  0.714438    TX
# 2004-01-01       77494           Katy     Harris  0.423210    TX
# 2004-01-01       79936        El Paso    El Paso  0.446429    TX
# 2004-01-01       77084        Houston     Harris  0.376047    TX
# 2004-01-01       77449           Katy     Harris  0.422115    TX
# ...                ...            ...        ...       ...   ...
# 2018-04-01       76941        Mertzon      Irion       NaN    TX
# 2018-04-01       79313          Anton    Hockley       NaN    TX
# 2018-04-01       79355         Plains     Yoakum       NaN    TX
# 2018-04-01       79366  Ransom Canyon    Lubbock  0.590488    TX
# 2018-04-01       77457      Matagorda  Matagorda  0.821314    TX
#
#                      std           mean        CV     value  year
# date
# 2004-01-01  38257.775512  227040.116279  0.168507  187700.0  2004
# 2004-01-01  33208.367605  266633.139535  0.124547  231800.0  2004
# 2004-01-01  10248.462666  113729.651163  0.090112   84000.0  2004
# 2004-01-01  14170.210695  130143.604651  0.108881  119400.0  2004
# 2004-01-01  16508.811448  134945.348837  0.122337  123900.0  2004
# ...                  ...            ...       ...       ...   ...
# 2018-04-01  13734.029878   99318.367347  0.138283  121600.0  2018
# 2018-04-01   5286.674724   54424.675325  0.097137   63300.0  2018
# 2018-04-01  12929.465872   78967.346939  0.163732   93500.0  2018
# 2018-04-01  25909.956515  189098.837209  0.137018  257500.0  2018
# 2018-04-01  32480.802116  175802.906977  0.184757  227300.0  2018
#
# [167292 rows x 10 columns]

# %%
# Select the first quantile
q1 = df['value'].quantile(.25)

# Select the third quantile
q3 = df['value'].quantile(.75)


# Create a filtered in between q1 & q3
filtered =df[(df['value']>=q1) 
             & (df['value']<=q3)]
filtered
# Out:
#             RegionName          City CountyName       ROI State           std  \
# date
# 2004-01-01       77084       Houston     Harris  0.376047    TX  14170.210695
# 2004-01-01       77449          Katy     Harris  0.422115    TX  16508.811448
# 2004-01-01       78660  Pflugerville     Travis  0.578674    TX  23031.089035
# 2004-01-01       77573   League City  Galveston  0.568086    TX  23867.673325
# 2004-01-01       79912       El Paso    El Paso  0.476452    TX  13149.347629
# ...                ...           ...        ...       ...   ...           ...
# 2018-04-01       76064      Maypearl      Ellis  0.659048    TX  15308.985812
# 2018-04-01       77577     Liverpool   Brazoria  0.761511    TX  17597.138719
# 2018-04-01       77663       Kountze     Hardin  0.312721    TX  11184.253614
# 2018-04-01       76941       Mertzon      Irion       NaN    TX  13734.029878
# 2018-04-01       79355        Plains     Yoakum       NaN    TX  12929.465872
#
#                      mean        CV     value  year
# date
# 2004-01-01  130143.604651  0.108881  119400.0  2004
# 2004-01-01  134945.348837  0.122337  123900.0  2004
# 2004-01-01  180093.023256  0.127884  153800.0  2004
# 2004-01-01  199441.279070  0.119673  166700.0  2004
# 2004-01-01  171614.534884  0.076621  127400.0  2004
# ...                   ...       ...       ...   ...
# 2018-04-01  136593.604651  0.112077  174200.0  2018
# 2018-04-01  108870.348837  0.161634  149200.0  2018
# 2018-04-01  131325.581395  0.085164  148600.0  2018
# 2018-04-01   99318.367347  0.138283  121600.0  2018
# 2018-04-01   78967.346939  0.163732   93500.0  2018
#
# [83728 rows x 10 columns]

# %%
df = filtered.merge(zip_codes, how='left', left_on='RegionName', right_on='ZIP Code', right_index=True)
df
# Out:
#             RegionName          City CountyName       ROI State           std  \
# date
# 2004-01-01       77084       Houston     Harris  0.376047    TX  14170.210695
# 2004-01-01       77449          Katy     Harris  0.422115    TX  16508.811448
# 2004-01-01       78660  Pflugerville     Travis  0.578674    TX  23031.089035
# 2004-01-01       77573   League City  Galveston  0.568086    TX  23867.673325
# 2004-01-01       79912       El Paso    El Paso  0.476452    TX  13149.347629
# ...                ...           ...        ...       ...   ...           ...
# 2018-04-01       76064      Maypearl      Ellis  0.659048    TX  15308.985812
# 2018-04-01       77577     Liverpool   Brazoria  0.761511    TX  17597.138719
# 2018-04-01       77663       Kountze     Hardin  0.312721    TX  11184.253614
# 2018-04-01       76941       Mertzon      Irion       NaN    TX  13734.029878
# 2018-04-01       79355        Plains     Yoakum       NaN    TX  12929.465872
#
#                      mean        CV     value  year  ...  Alternate names  \
# date                                                 ...
# 2004-01-01  130143.604651  0.108881  119400.0  2004  ...              NaN
# 2004-01-01  134945.348837  0.122337  123900.0  2004  ...              NaN
# 2004-01-01  180093.023256  0.127884  153800.0  2004  ...              NaN
# 2004-01-01  199441.279070  0.119673  166700.0  2004  ...              NaN
# 2004-01-01  171614.534884  0.076621  127400.0  2004  ...              NaN
# ...                   ...       ...       ...   ...  ...              ...
# 2018-04-01  136593.604651  0.112077  174200.0  2018  ...              NaN
# 2018-04-01  108870.348837  0.161634  149200.0  2018  ...              NaN
# 2018-04-01  131325.581395  0.085164  148600.0  2018  ...              NaN
# 2018-04-01   99318.367347  0.138283  121600.0  2018  ...              NaN
# 2018-04-01   78967.346939  0.163732   93500.0  2018  ...              NaN
#
#            Population (2019)  Housing units (2019)  \
# date
# 2004-01-01               NaN                   NaN
# 2004-01-01               NaN                   NaN
# 2004-01-01               NaN                   NaN
# 2004-01-01               NaN                   NaN
# 2004-01-01               NaN                   NaN
# ...                      ...                   ...
# 2018-04-01               NaN                   NaN
# 2018-04-01               NaN                   NaN
# 2018-04-01               NaN                   NaN
# 2018-04-01               NaN                   NaN
# 2018-04-01               NaN                   NaN
#
#            Median family income (2019) MFI percentile (2019) Latitude  \
# date
# 2004-01-01                         NaN                   NaN      NaN
# 2004-01-01                         NaN                   NaN      NaN
# 2004-01-01                         NaN                   NaN      NaN
# 2004-01-01                         NaN                   NaN      NaN
# 2004-01-01                         NaN                   NaN      NaN
# ...                                ...                   ...      ...
# 2018-04-01                         NaN                   NaN      NaN
# 2018-04-01                         NaN                   NaN      NaN
# 2018-04-01                         NaN                   NaN      NaN
# 2018-04-01                         NaN                   NaN      NaN
# 2018-04-01                         NaN                   NaN      NaN
#
#            Longitude Land area  Water area  state
# date
# 2004-01-01       NaN       NaN         NaN    NaN
# 2004-01-01       NaN       NaN         NaN    NaN
# 2004-01-01       NaN       NaN         NaN    NaN
# 2004-01-01       NaN       NaN         NaN    NaN
# 2004-01-01       NaN       NaN         NaN    NaN
# ...              ...       ...         ...    ...
# 2018-04-01       NaN       NaN         NaN    NaN
# 2018-04-01       NaN       NaN         NaN    NaN
# 2018-04-01       NaN       NaN         NaN    NaN
# 2018-04-01       NaN       NaN         NaN    NaN
# 2018-04-01       NaN       NaN         NaN    NaN
#
# [83728 rows x 24 columns]

# %%
df.drop(['ZIP Code', 'Type', 'State FIPS', 'Preferred name',
       'Alternate names', 'Median family income (2019)', 'Land area', 'Water area', 'state'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-d05b77fa3eda> in <module>
# ----> 1 df.drop(['ZIP Code', 'Type', 'State FIPS', 'Preferred name',
#       2        'Alternate names', 'Median family income (2019)', 'Land area', 'Water area', 'state'])
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3938                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    3939                 if errors == "raise" and labels_missing:
# -> 3940                     raise KeyError(f"{labels} not found in axis")
#    3941
#    3942             slicer = [slice(None)] * self.ndim
#
# KeyError: "['ZIP Code' 'Type' 'State FIPS' 'Preferred name' 'Alternate names'\n 'Median family income (2019)' 'Land area' 'Water area' 'state'] not found in axis"

# %%
df['Median family income (2019)'] = df['Median family income (2019)'].str.strip('$\n\t')

# %%
df['Median family income (2019)'] = df['Median family income (2019)'].str.replace(',','')

# %%
df = df[df['Median family income (2019)'].notna()]

# %%
df['median_family_income'] = df['Median family income (2019)'].astype(int)

# %%
df = pd.DataFrame(filtered)
df['RegionName']

# %%
df_prices = pd.DataFrame(df['value'], index = df.index)
df_prices

# %%
avg_prices = df_prices.groupby('date').aggregate({'value':'mean'})
avg_prices.plot()

# %%
std_prices = df_prices.groupby('date').aggregate({'value':'std'})
std_prices.plot()

# %%
med_prices = df_prices.groupby('date').aggregate({'value':'median'})
med_prices.plot()

# %%
from statsmodels.tsa.stattools import adfuller

def stationarity_check(df):
    roll_mean = df.rolling(window=12, center=False).mean()
    roll_std = df.rolling(window=12, center=False).std()
    
    df_test = adfuller(df)
    print('Results of Dickey-Fuller Test: \n')

    dfoutput = pd.Series(df_test[0:4], index=['Test Statistic', 'p-value', 
                                             '#Lags Used', 'Number of Observations Used'])
    for key,value in df_test[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    roll_mean.plot()
    roll_std.plot()
    return df_test

# %%
#results = stationarity_check(df_prices)
#results

# %%
df_log = np.log(df_prices)
fig = plt.figure(figsize=(15,8))
plt.plot(df_log, color='blue');

# %%
weight_roll_mean = df_log.ewm(halflife=4).mean()
df_log_wrm = df_log - weight_roll_mean
df_log_wrm.plot(figsize=(15,8))

# %%
type(df_log_wrm.index)

# %%
from statsmodels.tsa.arima.model import ARIMA

mod = ARIMA(df_log_wrm, order=(1, 0, 0))
res = mod.fit()
print(res.summary())

# %%
fig, ax = plt.subplots()

cmap = sns.cubehelix_palette(as_cmap=True)
points = ax.scatter(zip_codes['Longitude'], zip_codes['Latitude'], s=20, cmap='Blues')


ax.set_xlim((zip_codes['Longitude'].min(), zip_codes['Longitude'].max()))
ax.set_ylim((zip_codes['Latitude'].min(), zip_codes['Latitude'].max()))
fig.colorbar(points)
fig.set_size_inches(15,8)
plt.xlabel("Longitude")
plt.ylabel("Latitude");
